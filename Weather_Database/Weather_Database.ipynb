# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Initialize variables
set_count=1
record_count=1
city_data = []

# %%
# Create a set of random latitude and longitude combinations. Zip pairs up lats and lngs in pairs in the same index in their respective array into a tuple.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# Open Weather Map API Call
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
   
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.

    try:
        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | byron bay
# Processing Record 3 of Set 1 | provideniya
# Processing Record 4 of Set 1 | adrar
# Processing Record 5 of Set 1 | kantemirovka
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | baghdad
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | ilulissat
# Processing Record 10 of Set 1 | tarko-sale
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | riyadh
# Processing Record 14 of Set 1 | tuktoyaktuk
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | georgetown
# Processing Record 17 of Set 1 | schneverdingen
# Processing Record 18 of Set 1 | saint-ambroise
# Processing Record 19 of Set 1 | omboue
# Processing Record 20 of Set 1 | cidreira
# Processing Record 21 of Set 1 | los llanos de aridane
# Processing Record 22 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | kruisfontein
# Processing Record 26 of Set 1 | armidale
# Processing Record 27 of Set 1 | boa vista
# Processing Record 28 of Set 1 | perry
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | eyl
# Processing Record 31 of Set 1 | koper
# Processing Record 32 of Set 1 | aqtobe
# Processing Record 33 of Set 1 | port lincoln
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | toulepleu
# City not found. Skipping...
# Processing Record 36 of Set 1 | severo-kurilsk
# Processing Record 37 of Set 1 | norman wells
# Processing Record 38 of Set 1 | bethel
# Processing Record 39 of Set 1 | cockburn town
# Processing Record 40 of Set 1 | huarmey
# Processing Record 41 of Set 1 | leopold
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | kodiak
# Processing Record 44 of Set 1 | east london
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | padang
# Processing Record 47 of Set 1 | tiksi
# Processing Record 48 of Set 1 | vila franca do campo
# Processing Record 49 of Set 1 | itaituba
# Processing Record 50 of Set 1 | coueron
# Processing Record 1 of Set 2 | matara
# Processing Record 2 of Set 2 | carnarvon
# Processing Record 3 of Set 2 | torbay
# Processing Record 4 of Set 2 | mayna
# Processing Record 5 of Set 2 | arraial do cabo
# Processing Record 6 of Set 2 | marabba
# Processing Record 7 of Set 2 | mar del plata
# Processing Record 8 of Set 2 | khatanga
# Processing Record 9 of Set 2 | kashan
# Processing Record 10 of Set 2 | lagoa
# Processing Record 11 of Set 2 | hithadhoo
# Processing Record 12 of Set 2 | iqaluit
# Processing Record 13 of Set 2 | jamestown
# Processing Record 14 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 2 | auki
# Processing Record 16 of Set 2 | buchanan
# Processing Record 17 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 2 | qaqortoq
# Processing Record 19 of Set 2 | rikitea
# Processing Record 20 of Set 2 | maniitsoq
# Processing Record 21 of Set 2 | vallenar
# Processing Record 22 of Set 2 | komsomolskiy
# Processing Record 23 of Set 2 | lewistown
# Processing Record 24 of Set 2 | doha
# Processing Record 25 of Set 2 | lac du bonnet
# Processing Record 26 of Set 2 | diamantina
# Processing Record 27 of Set 2 | fayaoue
# Processing Record 28 of Set 2 | lebu
# Processing Record 29 of Set 2 | luanda
# Processing Record 30 of Set 2 | kutum
# Processing Record 31 of Set 2 | nadym
# Processing Record 32 of Set 2 | vaini
# Processing Record 33 of Set 2 | flin flon
# Processing Record 34 of Set 2 | mayo
# Processing Record 35 of Set 2 | narsaq
# Processing Record 36 of Set 2 | chicama
# Processing Record 37 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 2 | nelson bay
# Processing Record 39 of Set 2 | chokurdakh
# Processing Record 40 of Set 2 | vao
# Processing Record 41 of Set 2 | taltal
# Processing Record 42 of Set 2 | hobart
# Processing Record 43 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 2 | ribeira grande
# Processing Record 45 of Set 2 | palmas
# Processing Record 46 of Set 2 | luxor
# Processing Record 47 of Set 2 | vila velha
# Processing Record 48 of Set 2 | orchard homes
# Processing Record 49 of Set 2 | kaitangata
# Processing Record 50 of Set 2 | basco
# Processing Record 1 of Set 3 | matagami
# Processing Record 2 of Set 3 | castro
# Processing Record 3 of Set 3 | butaritari
# Processing Record 4 of Set 3 | yellowknife
# Processing Record 5 of Set 3 | ashqelon
# Processing Record 6 of Set 3 | yulara
# Processing Record 7 of Set 3 | mahebourg
# Processing Record 8 of Set 3 | baykit
# Processing Record 9 of Set 3 | cape town
# Processing Record 10 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 11 of Set 3 | ust-tsilma
# Processing Record 12 of Set 3 | sukhaya buyvola
# Processing Record 13 of Set 3 | suluq
# Processing Record 14 of Set 3 | bonavista
# Processing Record 15 of Set 3 | emerald
# Processing Record 16 of Set 3 | mount isa
# Processing Record 17 of Set 3 | longyearbyen
# Processing Record 18 of Set 3 | praia da vitoria
# Processing Record 19 of Set 3 | presidencia roque saenz pena
# Processing Record 20 of Set 3 | sitka
# Processing Record 21 of Set 3 | honningsvag
# Processing Record 22 of Set 3 | necochea
# Processing Record 23 of Set 3 | rawson
# Processing Record 24 of Set 3 | pasco
# Processing Record 25 of Set 3 | pisco
# Processing Record 26 of Set 3 | sur
# Processing Record 27 of Set 3 | bereda
# Processing Record 28 of Set 3 | mnogovershinnyy
# Processing Record 29 of Set 3 | kapaa
# Processing Record 30 of Set 3 | cabo san lucas
# Processing Record 31 of Set 3 | bredasdorp
# Processing Record 32 of Set 3 | riaba
# City not found. Skipping...
# Processing Record 33 of Set 3 | kavieng
# Processing Record 34 of Set 3 | westport
# Processing Record 35 of Set 3 | rodrigues alves
# Processing Record 36 of Set 3 | kokoda
# Processing Record 37 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 3 | abnub
# Processing Record 39 of Set 3 | saiki
# Processing Record 40 of Set 3 | wenatchee
# Processing Record 41 of Set 3 | goderich
# Processing Record 42 of Set 3 | nanakuli
# Processing Record 43 of Set 3 | saint-philippe
# Processing Record 44 of Set 3 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 45 of Set 3 | villarrica
# Processing Record 46 of Set 3 | cacule
# Processing Record 47 of Set 3 | atuona
# Processing Record 48 of Set 3 | airai
# Processing Record 49 of Set 3 | ca mau
# Processing Record 50 of Set 3 | bayan
# Processing Record 1 of Set 4 | valparaiso
# Processing Record 2 of Set 4 | angoram
# Processing Record 3 of Set 4 | yueyang
# Processing Record 4 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 5 of Set 4 | pundaguitan
# Processing Record 6 of Set 4 | pevek
# Processing Record 7 of Set 4 | chuy
# Processing Record 8 of Set 4 | yar-sale
# Processing Record 9 of Set 4 | abu samrah
# Processing Record 10 of Set 4 | ponta do sol
# Processing Record 11 of Set 4 | sinnamary
# Processing Record 12 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 4 | anadyr
# Processing Record 14 of Set 4 | qaanaaq
# Processing Record 15 of Set 4 | victoria
# Processing Record 16 of Set 4 | pitkyaranta
# Processing Record 17 of Set 4 | saskylakh
# Processing Record 18 of Set 4 | nata
# Processing Record 19 of Set 4 | wakiso
# Processing Record 20 of Set 4 | synya
# Processing Record 21 of Set 4 | pacifica
# Processing Record 22 of Set 4 | bambous virieux
# Processing Record 23 of Set 4 | curtea
# Processing Record 24 of Set 4 | saint george
# Processing Record 25 of Set 4 | caravelas
# Processing Record 26 of Set 4 | bjornevatn
# Processing Record 27 of Set 4 | belaya kholunitsa
# Processing Record 28 of Set 4 | vastervik
# City not found. Skipping...
# Processing Record 29 of Set 4 | umm kaddadah
# Processing Record 30 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 4 | kemi
# Processing Record 32 of Set 4 | roros
# Processing Record 33 of Set 4 | korla
# Processing Record 34 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 4 | bilma
# Processing Record 36 of Set 4 | shimoda
# Processing Record 37 of Set 4 | lensk
# Processing Record 38 of Set 4 | broome
# Processing Record 39 of Set 4 | felipe carrillo puerto
# Processing Record 40 of Set 4 | avarua
# Processing Record 41 of Set 4 | dingle
# Processing Record 42 of Set 4 | fort nelson
# Processing Record 43 of Set 4 | ostrovnoy
# Processing Record 44 of Set 4 | guerrero negro
# Processing Record 45 of Set 4 | metsovon
# City not found. Skipping...
# Processing Record 46 of Set 4 | tazmalt
# Processing Record 47 of Set 4 | quelimane
# Processing Record 48 of Set 4 | soyo
# Processing Record 49 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 4 | constitucion
# Processing Record 1 of Set 5 | iquique
# Processing Record 2 of Set 5 | holme
# Processing Record 3 of Set 5 | vanderhoof
# Processing Record 4 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 5 | vanimo
# Processing Record 6 of Set 5 | harper
# Processing Record 7 of Set 5 | chara
# Processing Record 8 of Set 5 | manokwari
# Processing Record 9 of Set 5 | souillac
# Processing Record 10 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 11 of Set 5 | leisure city
# Processing Record 12 of Set 5 | batken
# Processing Record 13 of Set 5 | lebork
# Processing Record 14 of Set 5 | sorland
# Processing Record 15 of Set 5 | nikolskoye
# Processing Record 16 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 5 | madang
# Processing Record 18 of Set 5 | aklavik
# Processing Record 19 of Set 5 | mantua
# Processing Record 20 of Set 5 | srednekolymsk
# Processing Record 21 of Set 5 | asekeyevo
# Processing Record 22 of Set 5 | murwara
# Processing Record 23 of Set 5 | wadi maliz
# Processing Record 24 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 5 | pangody
# Processing Record 26 of Set 5 | salalah
# Processing Record 27 of Set 5 | cabra
# Processing Record 28 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 5 | hilo
# Processing Record 30 of Set 5 | kropotkin
# Processing Record 31 of Set 5 | parthenay
# Processing Record 32 of Set 5 | farmington
# Processing Record 33 of Set 5 | coquimbo
# Processing Record 34 of Set 5 | praia
# Processing Record 35 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 5 | ashtian
# Processing Record 37 of Set 5 | faanui
# Processing Record 38 of Set 5 | nishihara
# Processing Record 39 of Set 5 | san quintin
# Processing Record 40 of Set 5 | meadow lake
# Processing Record 41 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 42 of Set 5 | hudiksvall
# Processing Record 43 of Set 5 | saldanha
# Processing Record 44 of Set 5 | dandong
# Processing Record 45 of Set 5 | oil city
# Processing Record 46 of Set 5 | kloulklubed
# Processing Record 47 of Set 5 | batagay-alyta
# Processing Record 48 of Set 5 | mandalgovi
# Processing Record 49 of Set 5 | tricase
# Processing Record 50 of Set 5 | duiven
# Processing Record 1 of Set 6 | dangara
# Processing Record 2 of Set 6 | hambantota
# Processing Record 3 of Set 6 | inta
# Processing Record 4 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 6 | isangel
# Processing Record 6 of Set 6 | upernavik
# Processing Record 7 of Set 6 | makinsk
# Processing Record 8 of Set 6 | garmsar
# Processing Record 9 of Set 6 | thompson
# Processing Record 10 of Set 6 | luderitz
# Processing Record 11 of Set 6 | beloha
# Processing Record 12 of Set 6 | ahipara
# Processing Record 13 of Set 6 | gisborne
# Processing Record 14 of Set 6 | tshikapa
# Processing Record 15 of Set 6 | payson
# Processing Record 16 of Set 6 | moose factory
# Processing Record 17 of Set 6 | elko
# Processing Record 18 of Set 6 | okhotsk
# Processing Record 19 of Set 6 | huatulco
# Processing Record 20 of Set 6 | mezen
# Processing Record 21 of Set 6 | diamantino
# Processing Record 22 of Set 6 | coihaique
# Processing Record 23 of Set 6 | tuatapere
# Processing Record 24 of Set 6 | linqiong
# Processing Record 25 of Set 6 | jinchang
# Processing Record 26 of Set 6 | krasnoselkup
# Processing Record 27 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 6 | nemuro
# Processing Record 29 of Set 6 | talara
# Processing Record 30 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 31 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 6 | dzilam gonzalez
# Processing Record 33 of Set 6 | bathsheba
# Processing Record 34 of Set 6 | polunochnoye
# Processing Record 35 of Set 6 | pindiga
# Processing Record 36 of Set 6 | jiuquan
# Processing Record 37 of Set 6 | tura
# Processing Record 38 of Set 6 | itoman
# Processing Record 39 of Set 6 | sept-iles
# Processing Record 40 of Set 6 | kondopoga
# Processing Record 41 of Set 6 | victor harbor
# Processing Record 42 of Set 6 | churapcha
# Processing Record 43 of Set 6 | berlevag
# Processing Record 44 of Set 6 | wilmington
# Processing Record 45 of Set 6 | palma del rio
# Processing Record 46 of Set 6 | fare
# Processing Record 47 of Set 6 | karamea
# City not found. Skipping...
# Processing Record 48 of Set 6 | ha noi
# Processing Record 49 of Set 6 | tabas
# Processing Record 50 of Set 6 | tual
# Processing Record 1 of Set 7 | leh
# Processing Record 2 of Set 7 | brae
# Processing Record 3 of Set 7 | fortuna
# Processing Record 4 of Set 7 | san cristobal
# Processing Record 5 of Set 7 | mokhsogollokh
# Processing Record 6 of Set 7 | mehamn
# Processing Record 7 of Set 7 | awjilah
# Processing Record 8 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 7 | camocim
# Processing Record 10 of Set 7 | yuzhnyy
# Processing Record 11 of Set 7 | namie
# Processing Record 12 of Set 7 | axim
# Processing Record 13 of Set 7 | baykalsk
# Processing Record 14 of Set 7 | tarnow
# Processing Record 15 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 7 | ugoofaaru
# Processing Record 17 of Set 7 | raudeberg
# Processing Record 18 of Set 7 | pyaozerskiy
# Processing Record 19 of Set 7 | hamilton
# Processing Record 20 of Set 7 | bowen
# Processing Record 21 of Set 7 | jibuti
# Processing Record 22 of Set 7 | kiomboi
# Processing Record 23 of Set 7 | abu dhabi
# Processing Record 24 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 7 | mahajanga
# Processing Record 26 of Set 7 | cap malheureux
# Processing Record 27 of Set 7 | roald
# Processing Record 28 of Set 7 | kulhudhuffushi
# Processing Record 29 of Set 7 | trikerion
# City not found. Skipping...
# Processing Record 30 of Set 7 | vardo
# Processing Record 31 of Set 7 | broken hill
# Processing Record 32 of Set 7 | clyde river
# Processing Record 33 of Set 7 | daniel flores
# Processing Record 34 of Set 7 | bom jardim
# Processing Record 35 of Set 7 | male
# Processing Record 36 of Set 7 | tasiilaq
# Processing Record 37 of Set 7 | deputatskiy
# Processing Record 38 of Set 7 | upington
# Processing Record 39 of Set 7 | kahului
# Processing Record 40 of Set 7 | dubinino
# Processing Record 41 of Set 7 | belyy yar
# Processing Record 42 of Set 7 | zabaykalsk
# Processing Record 43 of Set 7 | margate
# Processing Record 44 of Set 7 | dubbo
# Processing Record 45 of Set 7 | bengkulu
# Processing Record 46 of Set 7 | pokhara
# Processing Record 47 of Set 7 | sharlyk
# Processing Record 48 of Set 7 | yazd
# Processing Record 49 of Set 7 | minab
# Processing Record 50 of Set 7 | bafra
# Processing Record 1 of Set 8 | novomalorossiyskaya
# Processing Record 2 of Set 8 | port hardy
# Processing Record 3 of Set 8 | kigoma
# Processing Record 4 of Set 8 | ara
# Processing Record 5 of Set 8 | ishigaki
# Processing Record 6 of Set 8 | alofi
# Processing Record 7 of Set 8 | praya
# Processing Record 8 of Set 8 | cayenne
# Processing Record 9 of Set 8 | inirida
# Processing Record 10 of Set 8 | horki
# Processing Record 11 of Set 8 | markova
# Processing Record 12 of Set 8 | bansda
# City not found. Skipping...
# Processing Record 13 of Set 8 | bure
# Processing Record 14 of Set 8 | znamenskoye
# Processing Record 15 of Set 8 | port macquarie
# Processing Record 16 of Set 8 | eganville
# Processing Record 17 of Set 8 | samarai
# Processing Record 18 of Set 8 | itapetinga
# Processing Record 19 of Set 8 | kathu
# Processing Record 20 of Set 8 | college
# Processing Record 21 of Set 8 | codrington
# Processing Record 22 of Set 8 | the pas
# Processing Record 23 of Set 8 | dianopolis
# City not found. Skipping...
# Processing Record 24 of Set 8 | bintulu
# Processing Record 25 of Set 8 | richards bay
# Processing Record 26 of Set 8 | manta
# Processing Record 27 of Set 8 | bobrov
# Processing Record 28 of Set 8 | geraldton
# Processing Record 29 of Set 8 | bolgatanga
# Processing Record 30 of Set 8 | sandviken
# Processing Record 31 of Set 8 | san patricio
# Processing Record 32 of Set 8 | binga
# Processing Record 33 of Set 8 | olafsvik
# Processing Record 34 of Set 8 | aswan
# Processing Record 35 of Set 8 | kushima
# Processing Record 36 of Set 8 | aasiaat
# Processing Record 37 of Set 8 | nakamura
# Processing Record 38 of Set 8 | songea
# Processing Record 39 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 8 | santa marta
# Processing Record 41 of Set 8 | pemangkat
# Processing Record 42 of Set 8 | lyubinskiy
# Processing Record 43 of Set 8 | senno
# Processing Record 44 of Set 8 | kampot
# Processing Record 45 of Set 8 | mezhdurechensk
# Processing Record 46 of Set 8 | amazar
# Processing Record 47 of Set 8 | zhigansk
# Processing Record 48 of Set 8 | tala
# Processing Record 49 of Set 8 | katobu
# Processing Record 50 of Set 8 | tigil
# Processing Record 1 of Set 9 | macenta
# Processing Record 2 of Set 9 | borogontsy
# Processing Record 3 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 5 of Set 9 | nanortalik
# Processing Record 6 of Set 9 | wilmington island
# Processing Record 7 of Set 9 | omsukchan
# Processing Record 8 of Set 9 | acapulco
# Processing Record 9 of Set 9 | leningradskiy
# Processing Record 10 of Set 9 | verkhoyansk
# Processing Record 11 of Set 9 | nanpiao
# Processing Record 12 of Set 9 | hovd
# Processing Record 13 of Set 9 | tiznit
# Processing Record 14 of Set 9 | kodinsk
# Processing Record 15 of Set 9 | naze
# Processing Record 16 of Set 9 | guapiacu
# Processing Record 17 of Set 9 | talcahuano
# Processing Record 18 of Set 9 | mount gambier
# Processing Record 19 of Set 9 | gweta
# Processing Record 20 of Set 9 | grindavik
# Processing Record 21 of Set 9 | roma
# Processing Record 22 of Set 9 | san jeronimo
# Processing Record 23 of Set 9 | abasolo
# Processing Record 24 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 25 of Set 9 | ust-nera
# Processing Record 26 of Set 9 | kokopo
# Processing Record 27 of Set 9 | lamesa
# Processing Record 28 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 9 | arica
# Processing Record 30 of Set 9 | ereymentau
# Processing Record 31 of Set 9 | ocean springs
# Processing Record 32 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 33 of Set 9 | boksitogorsk
# Processing Record 34 of Set 9 | sao gabriel da cachoeira
# Processing Record 35 of Set 9 | toshkivka
# Processing Record 36 of Set 9 | hasaki
# Processing Record 37 of Set 9 | yerbogachen
# Processing Record 38 of Set 9 | marsh harbour
# Processing Record 39 of Set 9 | larsnes
# Processing Record 40 of Set 9 | thinadhoo
# Processing Record 41 of Set 9 | karasjok
# Processing Record 42 of Set 9 | kysyl-syr
# Processing Record 43 of Set 9 | ekpoma
# Processing Record 44 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 9 | te anau
# Processing Record 46 of Set 9 | belen
# Processing Record 47 of Set 9 | shahrud
# Processing Record 48 of Set 9 | kismayo
# Processing Record 49 of Set 9 | macieira de cambra
# Processing Record 50 of Set 9 | lata
# Processing Record 1 of Set 10 | tastur
# Processing Record 2 of Set 10 | gurupi
# Processing Record 3 of Set 10 | klaksvik
# Processing Record 4 of Set 10 | andili
# Processing Record 5 of Set 10 | alta floresta
# Processing Record 6 of Set 10 | lulea
# Processing Record 7 of Set 10 | kawalu
# Processing Record 8 of Set 10 | wanning
# Processing Record 9 of Set 10 | bambui
# Processing Record 10 of Set 10 | invermere
# Processing Record 11 of Set 10 | poronaysk
# Processing Record 12 of Set 10 | rzhaksa
# Processing Record 13 of Set 10 | novonukutskiy
# Processing Record 14 of Set 10 | simbahan
# Processing Record 15 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 16 of Set 10 | katsuura
# Processing Record 17 of Set 10 | anuradhapura
# Processing Record 18 of Set 10 | endicott
# Processing Record 19 of Set 10 | pilar
# Processing Record 20 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 10 | honghu
# Processing Record 22 of Set 10 | muros
# Processing Record 23 of Set 10 | santa monica
# Processing Record 24 of Set 10 | coahuayana
# Processing Record 25 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 26 of Set 10 | salinas
# Processing Record 27 of Set 10 | san jose
# Processing Record 28 of Set 10 | zakupne
# Processing Record 29 of Set 10 | zhanaozen
# Processing Record 30 of Set 10 | easley
# Processing Record 31 of Set 10 | khorixas
# Processing Record 32 of Set 10 | lalmohan
# Processing Record 33 of Set 10 | yershichi
# Processing Record 34 of Set 10 | hervey bay
# Processing Record 35 of Set 10 | mastic beach
# Processing Record 36 of Set 10 | lidkoping
# Processing Record 37 of Set 10 | balykshi
# Processing Record 38 of Set 10 | saint-pierre
# Processing Record 39 of Set 10 | asau
# Processing Record 40 of Set 10 | puerto escondido
# Processing Record 41 of Set 10 | aksu
# Processing Record 42 of Set 10 | ishinomaki
# Processing Record 43 of Set 10 | henties bay
# Processing Record 44 of Set 10 | springville
# Processing Record 45 of Set 10 | blagodatnoye
# Processing Record 46 of Set 10 | paramonga
# Processing Record 47 of Set 10 | namibe
# Processing Record 48 of Set 10 | maragogi
# Processing Record 49 of Set 10 | celestun
# Processing Record 50 of Set 10 | joue-les-tours
# Processing Record 1 of Set 11 | banjar
# Processing Record 2 of Set 11 | cherskiy
# Processing Record 3 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 4 of Set 11 | banda aceh
# Processing Record 5 of Set 11 | port-cartier
# Processing Record 6 of Set 11 | paracatu
# Processing Record 7 of Set 11 | nizhniy tsasuchey
# Processing Record 8 of Set 11 | mago
# Processing Record 9 of Set 11 | dukat
# Processing Record 10 of Set 11 | nalut
# Processing Record 11 of Set 11 | palu
# Processing Record 12 of Set 11 | severomuysk
# Processing Record 13 of Set 11 | darab
# Processing Record 14 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 15 of Set 11 | sao filipe
# Processing Record 16 of Set 11 | kaeo
# Processing Record 17 of Set 11 | elsmere
# Processing Record 18 of Set 11 | jinxiang
# Processing Record 19 of Set 11 | loandjili
# Processing Record 20 of Set 11 | diffa
# Processing Record 21 of Set 11 | yaroslavl
# Processing Record 22 of Set 11 | camana
# Processing Record 23 of Set 11 | hami
# Processing Record 24 of Set 11 | toftir
# City not found. Skipping...
# Processing Record 25 of Set 11 | waitati
# Processing Record 26 of Set 11 | yairipok
# Processing Record 27 of Set 11 | tucuman
# Processing Record 28 of Set 11 | north bend
# Processing Record 29 of Set 11 | angoche
# Processing Record 30 of Set 11 | ballymena
# Processing Record 31 of Set 11 | cabedelo
# Processing Record 32 of Set 11 | scarborough
# Processing Record 33 of Set 11 | vieira de leiria
# Processing Record 34 of Set 11 | storforshei
# Processing Record 35 of Set 11 | waipawa
# Processing Record 36 of Set 11 | champoton
# Processing Record 37 of Set 11 | setermoen
# Processing Record 38 of Set 11 | plainview
# Processing Record 39 of Set 11 | sarana
# Processing Record 40 of Set 11 | maltahohe
# Processing Record 41 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 11 | villa carlos paz
# Processing Record 43 of Set 11 | minas
# Processing Record 44 of Set 11 | shelburne
# Processing Record 45 of Set 11 | port hawkesbury
# Processing Record 46 of Set 11 | carutapera
# Processing Record 47 of Set 11 | castelldefels
# Processing Record 48 of Set 11 | touros
# Processing Record 49 of Set 11 | ancud
# Processing Record 50 of Set 11 | nizhniy kuranakh
# Processing Record 1 of Set 12 | lake havasu city
# Processing Record 2 of Set 12 | san policarpo
# Processing Record 3 of Set 12 | nuuk
# Processing Record 4 of Set 12 | namatanai
# Processing Record 5 of Set 12 | palmer
# Processing Record 6 of Set 12 | champerico
# Processing Record 7 of Set 12 | addi ugri
# City not found. Skipping...
# Processing Record 8 of Set 12 | chapada dos guimaraes
# Processing Record 9 of Set 12 | vikhorevka
# Processing Record 10 of Set 12 | balikpapan
# Processing Record 11 of Set 12 | chitral
# Processing Record 12 of Set 12 | buluang
# Processing Record 13 of Set 12 | progreso
# Processing Record 14 of Set 12 | la rioja
# Processing Record 15 of Set 12 | tommot
# Processing Record 16 of Set 12 | port elizabeth
# Processing Record 17 of Set 12 | leshukonskoye
# Processing Record 18 of Set 12 | acarau
# Processing Record 19 of Set 12 | port blair
# Processing Record 20 of Set 12 | kenora
# Processing Record 21 of Set 12 | pangnirtung
# Processing Record 22 of Set 12 | bollnas
# Processing Record 23 of Set 12 | jhalawar
# Processing Record 24 of Set 12 | aleksandrov gay
# Processing Record 25 of Set 12 | grand gaube
# Processing Record 26 of Set 12 | itarema
# Processing Record 27 of Set 12 | keelung
# Processing Record 28 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 29 of Set 12 | portland
# Processing Record 30 of Set 12 | tanout
# Processing Record 31 of Set 12 | samana
# Processing Record 32 of Set 12 | maceio
# Processing Record 33 of Set 12 | yaan
# Processing Record 34 of Set 12 | haines junction
# Processing Record 35 of Set 12 | rudbar
# Processing Record 36 of Set 12 | illapel
# Processing Record 37 of Set 12 | pacific grove
# Processing Record 38 of Set 12 | nome
# Processing Record 39 of Set 12 | ukiah
# Processing Record 40 of Set 12 | sungaipenuh
# Processing Record 41 of Set 12 | george town
# Processing Record 42 of Set 12 | pimentel
# Processing Record 43 of Set 12 | chittur
# Processing Record 44 of Set 12 | beringovskiy
# Processing Record 45 of Set 12 | mecca
# Processing Record 46 of Set 12 | cairns
# Processing Record 47 of Set 12 | uberaba
# Processing Record 48 of Set 12 | scoarta
# Processing Record 49 of Set 12 | changde
# Processing Record 50 of Set 12 | viedma
# Processing Record 1 of Set 13 | valentin gomez farias
# Processing Record 2 of Set 13 | west plains
# Processing Record 3 of Set 13 | moranbah
# Processing Record 4 of Set 13 | blagoveshchensk
# Processing Record 5 of Set 13 | muhos
# Processing Record 6 of Set 13 | lakatoro
# Processing Record 7 of Set 13 | okha
# Processing Record 8 of Set 13 | tromso
# Processing Record 9 of Set 13 | sao paulo de olivenca
# Processing Record 10 of Set 13 | halifax
# Processing Record 11 of Set 13 | sao joao da barra
# Processing Record 12 of Set 13 | dali
# Processing Record 13 of Set 13 | tukrah
# Processing Record 14 of Set 13 | amahai
# Processing Record 15 of Set 13 | ocampo
# Processing Record 16 of Set 13 | candido de abreu
# Processing Record 17 of Set 13 | kununurra
# Processing Record 18 of Set 13 | shihezi
# Processing Record 19 of Set 13 | gatton
# Processing Record 20 of Set 13 | qarqin
# Processing Record 21 of Set 13 | goranboy
# Processing Record 22 of Set 13 | langangen
# City not found. Skipping...
# Processing Record 23 of Set 13 | alice springs
# Processing Record 24 of Set 13 | wysokie mazowieckie
# Processing Record 25 of Set 13 | rorvik
# Processing Record 26 of Set 13 | chernyshevskiy
# Processing Record 27 of Set 13 | morristown
# Processing Record 28 of Set 13 | veraval
# Processing Record 29 of Set 13 | abidjan
# Processing Record 30 of Set 13 | sterling
# Processing Record 31 of Set 13 | fatezh
# Processing Record 32 of Set 13 | chicholi
# Processing Record 33 of Set 13 | aykhal
# Processing Record 34 of Set 13 | daru
# Processing Record 35 of Set 13 | puerto leguizamo
# Processing Record 36 of Set 13 | udachnyy
# Processing Record 37 of Set 13 | rafaela
# Processing Record 38 of Set 13 | moyale
# Processing Record 39 of Set 13 | jatiroto
# Processing Record 40 of Set 13 | sandur
# Processing Record 41 of Set 13 | kieta
# Processing Record 42 of Set 13 | sabalgarh
# Processing Record 43 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 44 of Set 13 | urumqi
# Processing Record 45 of Set 13 | comodoro rivadavia
# Processing Record 46 of Set 13 | makakilo city
# Processing Record 47 of Set 13 | vila
# Processing Record 48 of Set 13 | conceicao do araguaia
# Processing Record 49 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 50 of Set 13 | vestmannaeyjar
# Processing Record 1 of Set 14 | penzance
# Processing Record 2 of Set 14 | esperance
# Processing Record 3 of Set 14 | mabaruma
# Processing Record 4 of Set 14 | nara
# Processing Record 5 of Set 14 | rabo de peixe
# Processing Record 6 of Set 14 | mombetsu
# Processing Record 7 of Set 14 | pachino
# Processing Record 8 of Set 14 | denpasar
# Processing Record 9 of Set 14 | ondjiva
# Processing Record 10 of Set 14 | pyay
# Processing Record 11 of Set 14 | ixtapa
# Processing Record 12 of Set 14 | petauke
# Processing Record 13 of Set 14 | tucuma
# Processing Record 14 of Set 14 | marrakesh
# Processing Record 15 of Set 14 | altay
# Processing Record 16 of Set 14 | lins
# Processing Record 17 of Set 14 | naifaru
# Processing Record 18 of Set 14 | tateyama
# Processing Record 19 of Set 14 | ampanihy
# Processing Record 20 of Set 14 | quatis
# Processing Record 21 of Set 14 | jacareacanga
# Processing Record 22 of Set 14 | onega
# Processing Record 23 of Set 14 | kawambwa
# Processing Record 24 of Set 14 | fayetteville
# Processing Record 25 of Set 14 | port keats
# Processing Record 26 of Set 14 | wuwei
# Processing Record 27 of Set 14 | dvurechensk
# Processing Record 28 of Set 14 | mangrol
# Processing Record 29 of Set 14 | northam
# Processing Record 30 of Set 14 | khislavichi
# Processing Record 31 of Set 14 | balkanabat
# Processing Record 32 of Set 14 | svetlaya
# Processing Record 33 of Set 14 | sampit
# Processing Record 34 of Set 14 | amapa
# Processing Record 35 of Set 14 | jalu
# Processing Record 36 of Set 14 | bubaque
# Processing Record 37 of Set 14 | gat
# Processing Record 38 of Set 14 | zhireken
# Processing Record 39 of Set 14 | hede
# Processing Record 40 of Set 14 | correia pinto
# Processing Record 41 of Set 14 | dzhebariki-khaya
# Processing Record 42 of Set 14 | sabha
# Processing Record 43 of Set 14 | bud
# Processing Record 44 of Set 14 | kang
# Processing Record 45 of Set 14 | kisangani
# Processing Record 46 of Set 14 | meulaboh
# Processing Record 47 of Set 14 | zyryanka
# Processing Record 48 of Set 14 | balaguer
# Processing Record 49 of Set 14 | nuevitas
# Processing Record 50 of Set 14 | simao
# Processing Record 1 of Set 15 | kupang
# Processing Record 2 of Set 15 | half moon bay
# Processing Record 3 of Set 15 | changying
# Processing Record 4 of Set 15 | saint anthony
# Processing Record 5 of Set 15 | palana
# Processing Record 6 of Set 15 | baiyin
# Processing Record 7 of Set 15 | la ronge
# Processing Record 8 of Set 15 | cascais
# Processing Record 9 of Set 15 | talnakh
# Processing Record 10 of Set 15 | charters towers
# Processing Record 11 of Set 15 | palafrugell
# Processing Record 12 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 13 of Set 15 | ararat
# Processing Record 14 of Set 15 | santa isabel do rio negro
# Processing Record 15 of Set 15 | baicheng
# Processing Record 16 of Set 15 | yurimaguas
# Processing Record 17 of Set 15 | severodvinsk
# Processing Record 18 of Set 15 | furstenfeld
# Processing Record 19 of Set 15 | kamenka
# Processing Record 20 of Set 15 | kilimatinde
# Processing Record 21 of Set 15 | sandi
# Processing Record 22 of Set 15 | flinders
# Processing Record 23 of Set 15 | toora-khem
# Processing Record 24 of Set 15 | fairbanks
# Processing Record 25 of Set 15 | tonantins
# Processing Record 26 of Set 15 | senanga
# Processing Record 27 of Set 15 | ribeira brava
# Processing Record 28 of Set 15 | liverpool
# Processing Record 29 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 30 of Set 15 | darnah
# Processing Record 31 of Set 15 | khonsa
# Processing Record 32 of Set 15 | sishui
# Processing Record 33 of Set 15 | shar
# Processing Record 34 of Set 15 | mao
# Processing Record 35 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 15 | dicabisagan
# Processing Record 37 of Set 15 | wewak
# Processing Record 38 of Set 15 | kijang
# Processing Record 39 of Set 15 | yeppoon
# Processing Record 40 of Set 15 | wana
# Processing Record 41 of Set 15 | kodino
# Processing Record 42 of Set 15 | saint-joseph
# Processing Record 43 of Set 15 | skibbereen
# Processing Record 44 of Set 15 | ust-kuyga
# Processing Record 45 of Set 15 | uyuni
# Processing Record 46 of Set 15 | ulaangom
# Processing Record 47 of Set 15 | kamaishi
# Processing Record 48 of Set 15 | umm lajj
# Processing Record 49 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 15 | karatau
# Processing Record 1 of Set 16 | luau
# Processing Record 2 of Set 16 | santa maria
# Processing Record 3 of Set 16 | baracoa
# Processing Record 4 of Set 16 | tinqueux
# Processing Record 5 of Set 16 | cortez
# Processing Record 6 of Set 16 | subaytilah
# City not found. Skipping...
# Processing Record 7 of Set 16 | matamoros
# Processing Record 8 of Set 16 | muroto
# Processing Record 9 of Set 16 | bandar-e lengeh
# Processing Record 10 of Set 16 | balod
# Processing Record 11 of Set 16 | batemans bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0        New Norfolk      AU -42.7826  147.0587     48.92        86
# 1          Byron Bay      AU -28.6500  153.6167     60.35        79
# 2        Provideniya      RU  64.3833 -173.3000     46.27        77
# 3              Adrar      MR  20.5022  -10.0711     94.96        28
# 4       Kantemirovka      RU  49.7089   39.8592     59.45        94
# ..               ...     ...      ...       ...       ...       ...
# 697        Matamoros      MX  25.5333 -103.2500     96.91        20
# 698           Muroto      JP  33.2833  134.1500     79.39        68
# 699  Bandar-E Lengeh      IR  26.5579   54.8807     91.02        76
# 700            Balod      IN  20.7300   81.2047     75.18        92
# 701     Batemans Bay      AU -35.7167  150.1833     51.10        65
#
#      Cloudiness  Wind Speed Current Description
# 0           100        2.10          light rain
# 1            84       13.02       broken clouds
# 2            96        6.80     overcast clouds
# 3            93       10.96     overcast clouds
# 4            19        7.07          few clouds
# ..          ...         ...                 ...
# 697          75        8.05       broken clouds
# 698          74        2.21       broken clouds
# 699          94       10.47     overcast clouds
# 700         100        6.42     overcast clouds
# 701          38        1.81    scattered clouds
#
# [702 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
